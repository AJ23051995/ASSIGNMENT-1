# %% [markdown]
# # QUESTION 1-
# Write a python program to display all the header tags from Wikipedia.org

# %%
import requests
from bs4 import BeautifulSoup
url=requests.get('https://en.wikipedia.org')
soup=BeautifulSoup(url.text,'html.parser')
story=soup.find_all(['h1','h2','h3'])
for i in story:
    print(i)
# Out:
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none"><span class="mw-page-title-main">Main Page</span></h1>
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
# <h2 class="mp-h2" id="mp-tfl-h2"><span id="From_today.27s_featured_list"></span><span class="mw-headline" id="From_today's_featured_list">From today's featured list</span></h2>
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
# <h2>Navigation menu</h2>
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span class="vector-menu-heading-label">Personal tools</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span class="vector-menu-heading-label">Namespaces</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-views-label">
# <span class="vector-menu-heading-label">Views</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span class="vector-menu-heading-label">Navigation</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span class="vector-menu-heading-label">Contribute</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span class="vector-menu-heading-label">In other projects</span>
# </h3>
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span class="vector-menu-heading-label">Languages</span>
# </h3>

# %% [markdown]
# # QUESTION -2
# Write a python program to display IMDB's Top rated 100 movies(i.e.name,rating,year of release)
# and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
#to collect the english translation of datas
headers={'Accept-Language':'en-US,en;q=0.5'}
#data of 50 movies in each page,hence each request fetches 50 movies data making it a total of 100 movies.
request=requests.get('https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc',headers=headers)
request1=requests.get('https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&start=51&ref_=adv_nxt',headers=headers)
Soup=BeautifulSoup(request.content)
Soup1=BeautifulSoup(request1.content)
#append data of both Soup and Soup1
Soup.append(Soup1)
MoviesName=[]
Year=[]
Rating=[]
movies=Soup.find_all("div",class_='lister-item mode-advanced')
for m in movies:
    name=m.h3.a.text
    year=m.h3.find('span',class_='lister-item-year text-muted unbold').text
    rate=m.strong.text
    MoviesName.append(name)
    Year.append(year)
    Rating.append(rate)
Movies=pd.DataFrame({'Movie':MoviesName,'Year of Release':Year,'Rating':Rating},index=range(1,101))
Movies.head(20)
# Out:
#                                                 Movie Year of Release Rating
# 1                            The Shawshank Redemption          (1994)    9.3
# 2                                       The Godfather          (1972)    9.2
# 3                                     The Dark Knight          (2008)    9.0
# 4       The Lord of the Rings: The Return of the King          (2003)    9.0
# 5                                    Schindler's List          (1993)    9.0
# 6                               The Godfather Part II          (1974)    9.0
# 7                                        12 Angry Men          (1957)    9.0
# 8                                        Pulp Fiction          (1994)    8.9
# 9                                           Inception          (2010)    8.8
# 10              The Lord of the Rings: The Two Towers          (2002)    8.8
# 11                                         Fight Club          (1999)    8.8
# 12  The Lord of the Rings: The Fellowship of the Ring          (2001)    8.8
# 13                                       Forrest Gump          (1994)    8.8
# 14                     The Good, the Bad and the Ugly          (1966)    8.8
# 15                                         The Matrix          (1999)    8.7
# 16                                         Goodfellas          (1990)    8.7
# 17     Star Wars: Episode V - The Empire Strikes Back          (1980)    8.7
# 18                    One Flew Over the Cuckoo's Nest          (1975)    8.7
# 19                                       Interstellar          (2014)    8.6
# 20                                        City of God          (2002)    8.6

# %% [markdown]
# # QUESTION-3
# Write a python program to display IMDB's top rated 100 indian movies(i.e.name,rating,year of release) and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
req=requests.get('https://www.imdb.com/india/top-rated-indian-movies/')
Soup=BeautifulSoup(req.content)
movs=Soup.find_all('td',class_='titleColumn')
movs100=movs[0:100]
Mname=[]
Year=[]
for m in movs100:
    name=m.a.text
    year=m.span.text
    Mname.append(name)
    Year.append(year)
rate=Soup.find_all('td',class_='ratingColumn imdbRating')
rate100=rate[0:100]
IMDB=[]
for r in rate100:
    imdb=r.strong.text
    IMDB.append(imdb)
INDTOP=pd.DataFrame({'Name':Mname,'Year of Release':Year,'Rating':IMDB},index=range(1,101))
INDTOP
# Out:
#                                     Name Year of Release Rating
# 1    Ramayana: The Legend of Prince Rama          (1993)    8.5
# 2             Rocketry: The Nambi Effect          (2022)    8.4
# 3                            777 Charlie          (2022)    8.4
# 4                                Golmaal          (1979)    8.4
# 5                                Nayakan          (1987)    8.4
# ..                                   ...             ...    ...
# 96                        Kaakkaa Muttai          (2014)    8.0
# 97                           Ustad Hotel          (2012)    8.0
# 98              Theeran Adhigaaram Ondru          (2017)    8.0
# 99                       Rang De Basanti          (2006)    8.0
# 100                               Angoor          (1982)    8.0
#
# [100 rows x 3 columns]

# %% [markdown]
# # QUESTION-4
# Write apython program to display list of respected former presidents of India(i.e.Name,Term of office) from https://presidentofindia.nic.in/former-presidents.htm

# %%
from bs4 import BeautifulSoup
import requests

page=requests.get('https://presidentofindia.nic.in/former-presidents.htm')
page


soup=BeautifulSoup(page.content)
soup


first_title=soup.find('h3')
first_title


first_title=[]
for i in soup.find_all('h3'):
    first_title.append(i.text)
first_title


Term=[]
for i in soup.find_all('p'):
    Term.append(i.text)
Term


Detail=[]
for i in soup.find_all('div', class_="presidentListing"):
    Detail.append(i.text)
Detail


import pandas as pd
df=pd.DataFrame({"PresidentiaL List":Detail})
df
# Out:
#                                     PresidentiaL List
# 0   \nShri Ram Nath Kovind (birth - 1945)\nTerm of...
# 1   \nShri Pranab Mukherjee (1935-2020)\nTerm of O...
# 2   \nSmt Pratibha Devisingh Patil (birth - 1934)\...
# 3   \nDR. A.P.J. Abdul Kalam (1931-2015)\nTerm of ...
# 4   \nShri K. R. Narayanan (1920 - 2005)\nTerm of ...
# 5   \nDr Shankar Dayal Sharma (1918-1999)\nTerm of...
# 6   \nShri R Venkataraman (1910-2009)\nTerm of Off...
# 7   \nGiani Zail Singh (1916-1994)\nTerm of Office...
# 8   \nShri Neelam Sanjiva Reddy (1913-1996)\nTerm ...
# 9   \nDr. Fakhruddin Ali Ahmed (1905-1977)\nTerm o...
# 10  \nShri Varahagiri Venkata Giri (1894-1980)\nTe...
# 11  \nDr. Zakir Husain (1897-1969)\nTerm of Office...
# 12  \nDr. Sarvepalli Radhakrishnan (1888-1975)\nTe...
# 13  \nDr. Rajendra Prasad (1884-1963) \nTerm of Of...

# %% [markdown]
# # QUESTION-5
# Write a python program to scrape cricket ranking from icc-cricket.com.You have to scrape:
#
# a-Top 10 ODI Team in men's Cricket along with records of matches,points and rating.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
info=requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
soup=BeautifulSoup(info.content)
team=soup.find_all('tr',class_=('rankings-block__banner','table-body'))
top10=team[0:10]
data = {'Team_Name':[],'Matches': [],'Points': [],'Rating':[]}
for i in top10:
    pnt=i.find_all('td',recursive=True)
    data['Team_Name'].append(i.find('span',class_='u-hide-phablet').text)
    data['Matches'].append(pnt[2].text)
    data['Points'].append(pnt[3].text)
    data['Rating'].append(pnt[4].text.replace('\n',''))
MenTeam=pd.DataFrame(data,index=range(1,11))
MenTeam
# Out:
#        Team_Name Matches Points  \
# 1    New Zealand      23  2,670
# 2        England      30  3,400
# 3      Australia      32  3,572
# 4          India      35  3,866
# 5       Pakistan      22  2,354
# 6   South Africa      24  2,392
# 7     Bangladesh      30  2,753
# 8      Sri Lanka      30  2,677
# 9    Afghanistan      19  1,380
# 10   West Indies      41  2,902
#
#                                                Rating
# 1                               116               ...
# 2                                                 113
# 3                                                 112
# 4                                                 110
# 5                                                 107
# 6                                                 100
# 7                                                  92
# 8                                                  89
# 9                                                  73
# 10                                                 71

# %% [markdown]
# # QUESTION-5
# b-Top 10 ODI Batsmen along with the records of their team and rating.

# %%
req=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
soup=BeautifulSoup(req.content)
bowler=soup.find_all('tr',class_=('rankings-block__banner','table-body'))
Top10=bowler[0:10]
bdata={'Player_Name':[],'Team_Name': [], 'Rating':[]}
for i in Top10:
    bat=i.find_all('td',recursive=True)
    bdata['Player_Name'].append(bat[1].text.replace('\n',''))
    bdata['Team_Name'].append(bat[2].text.replace('\n',''))
    bdata['Rating'].append(bat[3].text.replace('\n',''))
ODIBOWL=pd.DataFrame(bdata,index=range(1,11))
ODIBOWL
# Out:
#          Player_Name               Team_Name Rating
# 1        Trent Boult  NZ                        775
# 2     Josh Hazlewood                     AUS    727
# 3   Mujeeb Ur Rahman                     AFG    676
# 4     Mitchell Starc                     AUS    665
# 5     Shaheen Afridi                     PAK    661
# 6      Mohammad Nabi                     AFG    657
# 7         Adam Zampa                     AUS    655
# 8       Mehedi Hasan                     BAN    655
# 9         Matt Henry                      NZ    654
# 10       Rashid Khan                     AFG    651

# %% [markdown]
# # QUESTION-5
# c-TOP 10 ODI bowlers along with the records of their team and rating.

# %%
req=requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
soup=BeautifulSoup(req.content)
player=soup.find_all('tr',class_=('rankings-block__banner','table-body'))
Top10=player[0:10]
data={'Player_Name':[],'Team_Name': [], 'Rating':[]}
for i in Top10:
    bat=i.find_all('td',recursive=True)
    data['Player_Name'].append(bat[1].text.replace('\n',''))
    data['Team_Name'].append(bat[2].text.replace('\n',''))
    data['Rating'].append(bat[3].text.replace('\n',''))
ODIBATSMAN=pd.DataFrame(data,index=range(1,11))
ODIBATSMAN
# Out:
#               Player_Name                Team_Name Rating
# 1              Babar Azam  PAK                        890
# 2             Imam-ul-Haq                      PAK    779
# 3   Rassie van der Dussen                       SA    766
# 4         Quinton de Kock                       SA    759
# 5            David Warner                      AUS    747
# 6             Virat Kohli                      IND    722
# 7             Steve Smith                      AUS    719
# 8            Rohit Sharma                      IND    718
# 9          Jonny Bairstow                      ENG    710
# 10            Ross Taylor                       NZ    701

# %% [markdown]
# # QUESTION-6
# Write a python program to scrape cricket rankings from icc-cricket.com.You have to scrape:
#
# a-Top 10 ODI teams in womens cricket along with the records of matches,points and rating.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
req=requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
soup=BeautifulSoup(req.content)
team=soup.find_all('tr',class_=('rankings-block__banner','table-body'))
top10=team[0:10]
data = {'Team_Name':[],'Matches': [],'Points': [],'Rating':[]}

for i in top10:
    pnt=i.find_all('td',recursive=True)
    data['Team_Name'].append(i.find('span',class_='u-hide-phablet').text)
    data['Matches'].append(pnt[2].text)
    data['Points'].append(pnt[3].text)
    data['Rating'].append(pnt[4].text.strip().replace('\n',''))
WomenTeam=pd.DataFrame(data,index=range(1,11))
WomenTeam
# Out:
#        Team_Name Matches Points Rating
# 1      Australia      18  3,061    170
# 2   South Africa      26  3,098    119
# 3        England      25  2,904    116
# 4          India      27  2,820    104
# 5    New Zealand      24  2,425    101
# 6    West Indies      24  2,334     97
# 7     Bangladesh      12    932     78
# 8       Thailand       8    572     72
# 9       Pakistan      24  1,519     63
# 10     Sri Lanka       8    353     44

# %% [markdown]
# # QUESTION-6
# b-Top 10 women's ODI batting players along with the records of their team and rating.

# %%
req=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/bowling')
soup=BeautifulSoup(req.content)
bowler=soup.find_all('tr',class_=('rankings-block__banner','table-body'))
Top10=bowler[0:10]
bdata={'Player_Name':[],'Team_Name': [], 'Rating':[]}
for i in Top10:
    bat=i.find_all('td',recursive=True)
    bdata['Player_Name'].append(bat[1].text.replace('\n',''))
    bdata['Team_Name'].append(bat[2].text.replace('\n',''))
    bdata['Rating'].append(bat[3].text.replace('\n',''))
ODIBOWL=pd.DataFrame(bdata,index=range(1,11))
ODIBOWL
# Out:
#             Player_Name                Team_Name Rating
# 1     Sophie Ecclestone  ENG                        739
# 2         Jess Jonassen                      AUS    725
# 3          Megan Schutt                      AUS    722
# 4        Shabnim Ismail                       SA    722
# 5        Jhulan Goswami                      IND    698
# 6       Hayley Matthews                       WI    671
# 7            Kate Cross                      ENG    657
# 8        Ayabonga Khaka                       SA    634
# 9   Rajeshwari Gayakwad                      IND    617
# 10       Marizanne Kapp                       SA    598

# %% [markdown]
# # QUESTION -6
# C-TOP 10 Women's ODI all-rounder along with the records of their team and rating.

# %%
req=requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
soup=BeautifulSoup(req.content)
player=soup.find_all('tr',class_=('rankings-block__banner','table-body'))
Top10=player[0:10]
data={'Player_Name':[],'Team_Name': [], 'Rating':[]}
for i in Top10:
    bat=i.find_all('td',recursive=True)
    data['Player_Name'].append(bat[1].text.replace('\n',''))
    data['Team_Name'].append(bat[2].text.replace('\n',''))
    data['Rating'].append(bat[3].text.replace('\n',''))
ODIBATSMAN=pd.DataFrame(data,index=range(1,11))
ODIBATSMAN
# Out:
#             Player_Name                Team_Name Rating
# 1          Alyssa Healy  AUS                        785
# 2           Beth Mooney                      AUS    749
# 3       Laura Wolvaardt                       SA    732
# 4        Natalie Sciver                      ENG    725
# 5      Harmanpreet Kaur                      IND    716
# 6       Smriti Mandhana                      IND    714
# 7           Meg Lanning                      AUS    710
# 8        Rachael Haynes                      AUS    701
# 9     Amy Satterthwaite                       NZ    661
# 10  Chamari Athapaththu                       SL    655

# %% [markdown]
# # QUESTION-7
#  write a python program to scrape mentioned nnews details from https://www.cnbc.com/world/?region=world:
#
#  a)HEADLINE

# %%
import requests
from bs4 import BeautifulSoup

page=requests.get('https://www.cnbc.com/world/?region=world')
page

news=BeautifulSoup(page.content)
news

# # Headline
Headline=news.find('div',class_='RiverHeadline-headline RiverHeadline-hasThumbnail')
Headline

Headline.text

Headline=[]
for i in news.find_all('div',class_='RiverHeadline-headline RiverHeadline-hasThumbnail'):
   Headline.append(i.text)
Headline
# Out:
# ["Peter Thiel's VC fund backs TreeCard, a fintech that plants trees when you spend",
#  "Russia 'planning something' in southern Ukraine, Kyiv warns; Russians could be advancing in Donetsk",
#  'As Wall Street gets bearish, these global stocks with margin growth could be safe bets',
#  "Bitcoin tops $17,000 for the first time in two weeks but analysts don't expect the bounce to stick",
#  "Brace for double-digit percentage drop to hit stocks, Morgan Stanley's Mike Wilson warns",
#  "China's factory activity at lowest reading since April; Hong Kong stocks briefly rise 2%",
#  "Goldman Sachs' Currie says oil stocks are trading 'far below' their long-term trend",
#  'These are shaping up to be the best and worst luxury real estate markets for 2023',
#  'Pulisic goal advances U.S. in World Cup with 1-0 win over Iran',
#  'Hoping to beat the tourist crowd on your trip to Japan? That ship has sailed',
#  'Weakness in Apple’s stock could be a warning for the broader market, chart technicians say',
#  'CNBC Stock World Cup 2022: Recap of winners and losers so far',
#  'Former Chinese President Jiang Zemin dies at age 96, state media reports',
#  "China's Tencent bets on cloud computing growth abroad as its core video games business takes a beating",
#  "'Losing is not an option': Putin is 'desperate' to avoid defeat in Ukraine as anxiety rises in Moscow",
#  'Tesla is still dominant, but its U.S. market share is eroding as cheaper EVs arrive',
#  "'Golden era' for Britain and China’s relationship is over, UK PM Rishi Sunak says",
#  'iPhone maker Foxconn entices angry workers in China to return as Apple faces supply crunch',
#  "This 30-year-old quit her Amazon job—now she makes $40K/month in passive income: 'I work 2 hours a day'",
#  'Chinese astronauts board space station in historic mission']

# %% [markdown]
# # QUESTION-7
#
# b)TIME

# %%
Time=news.find('time')
Time


Time.text


Time=[]
for i in news.find_all('time'):
   Time.append(i.text)
Time
# Out:
# ['2 Min Ago',
#  '6 Min Ago',
#  '60 Min Ago',
#  '1 Hour Ago',
#  '2 Hours Ago',
#  '2 Hours Ago',
#  '3 Hours Ago',
#  '3 Hours Ago',
#  '4 Hours Ago',
#  '4 Hours Ago',
#  '5 Hours Ago',
#  '9 Hours Ago',
#  '9 Hours Ago',
#  '9 Hours Ago',
#  '9 Hours Ago',
#  '10 Hours Ago',
#  '10 Hours Ago',
#  '10 Hours Ago',
#  '11 Hours Ago',
#  '11 Hours Ago',
#  '11 Hours Ago',
#  '11 Hours Ago',
#  '11 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '12 Hours Ago',
#  '13 Hours Ago']

# %% [markdown]
# # QUESTION-7
#
# NEWSLINK

# %%
# # Newslink

# In[69]:


url = "https://www.cnbc.com/world/?region=world"
webpage = requests.get(url) 
trav = BeautifulSoup(webpage.content, "html.parser")
for link in trav.find_all('a'):
    print(type(link), " ", link)


trav.text
# Out:
# <class 'bs4.element.Tag'>   <a class="JumpLink-link" href="#MainContent">Skip Navigation</a>
# <class 'bs4.element.Tag'>   <a class="branding-menu-logo" href="//www.cnbc.com/world/"><img alt="logo" class="branding-menu-logo" src="https://static-redesign.cnbcfm.com/dist/0dbbcac4aae29ae1ab0b.svg"/></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu
a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/video-ceo-interviews/" tabindex="-1">CEO Interviews</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/europe-television/" tabindex="-1">Europe TV</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/asia-business-day/" tabindex="-1">Asia TV</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/podcast/" tabindex="-1">CNBC Podcasts</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/digital-original/" tabindex="-1">Digital Originals</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/watchlist/"><span class="icon-watchlist"></span><span class="nav-menu-buttonText">Watchlist</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/investingclub/"><span class="icon-investing_club"></span><span class="nav-menu-buttonText">Investing Club</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/investingclub/charitable-trust/" tabindex="-1">Trust Portfolio</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/investingclub/analysis/" tabindex="-1">Analysis</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/investingclub/trade-alerts/" tabindex="-1">Trade Alerts</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/investingclub/video/" tabindex="-1">Video</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/investingclub/education/" tabindex="-1">Education</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/pro/"><span class="icon-pro"></span><span class="nav-menu-buttonText">PRO</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/pro/news/" tabindex="-1">Pro News</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="/pro/" tabindex="-1">Pro Live</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="#" tabindex="-1">Subscribe</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-subLink" href="#" tabindex="-1">Sign In</a>
# <class 'bs4.element.Tag'>   <a href="/make-it/" title="makeit">Make It<span class="icon-offsite-arrow"></span></a>
# <class 'bs4.element.Tag'>   <a href="/?region=usa">USA</a>
# <class 'bs4.element.Tag'>   <a class="account-menu-underlineLabel" href="/world/">INTL</a>
# <class 'bs4.element.Tag'>   <a href="/watchlist/">Watchlist</a>
# <class 'bs4.element.Tag'>   <a href="#">SIGN IN</a>
# <class 'bs4.element.Tag'>   <a href="#">Create free account</a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-logoContainer" href="/"><img alt="logo" class="nav-menu-logo" src="https://static-redesign.cnbcfm.com/dist/79ea413ac8a9ee99cad0.svg"/></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/markets/"><span class="icon-markets"></span><span class="nav-menu-buttonText">Markets</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/business/"><span class="icon-news"></span><span class="nav-menu-buttonText">Business</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/investing/"><span class="icon-investing"></span><span class="nav-menu-buttonText">Investing</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/technology/"><span class="icon-tech"></span><span class="nav-menu-buttonText">Tech</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/politics/"><span class="icon-politics"></span><span class="nav-menu-buttonText">Politics</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/tv/"><span class="icon-cnbctv"></span><span class="nav-menu-buttonText">CNBC TV</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/watchlist/"><span class="icon-watchlist"></span><span class="nav-menu-buttonText">Watchlist</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/investingclub/"><span class="icon-investing_club"></span><span class="nav-menu-buttonText">Investing Club</span></a>
# <class 'bs4.element.Tag'>   <a class="nav-menu-button" href="/pro/"><span class="icon-pro"></span><span class="nav-menu-buttonText">PRO</span></a>
# <class 'bs4.element.Tag'>   <a class="MarketCard-container" href="#"><div class="MarketCard-row"><span class="MarketCard-symbol"></span><span class="MarketCard-stockPosition">---</span></div><div class="MarketCard-row"><div class="MarketCard-changeData"><span class="MarketCard-changesPts">---</span><span class="MarketCard-changesPct">---</span></div></div><div class="MarketCard-row"></div></a>
# <class 'bs4.element.Tag'>   <a class="MarketCard-container" href="#"><div class="MarketCard-row"><span class="MarketCard-symbol"></span><span class="MarketCard-stockPosition">---</span></div><div class="MarketCard-row"><div class="MarketCard-changeData"><span class="MarketCard-changesPts">---</span><span class="MarketCard-changesPct">---</span></div></div><div class="MarketCard-row"></div></a>
# <class 'bs4.element.Tag'>   <a class="MarketCard-container" href="#"><div class="MarketCard-row"><span class="MarketCard-symbol"></span><span class="MarketCard-stockPosition">---</span></div><div class="MarketCard-row"><div class="MarketCard-changeData"><span class="MarketCard-changesPts">---</span><span class="MarketCard-changesPct">---</span></div></div><div class="MarketCard-row"></div></a>
# <class 'bs4.element.Tag'>   <a class="MarketCard-container" href="#"><div class="MarketCard-row"><span class="MarketCard-symbol"></span><span class="MarketCard-stockPosition">---</span></div><div class="MarketCard-row"><div class="MarketCard-changeData"><span class="MarketCard-changesPts">---</span><span class="MarketCard-changesPct">---</span></div></div><div class="MarketCard-row"></div></a>
# <class 'bs4.element.Tag'>   <a class="MarketCard-container" href="#"><div class="MarketCard-row"><span class="MarketCard-symbol"></span><span class="MarketCard-stockPosition">---</span></div><div class="MarketCard-row"><div class="MarketCard-changeData"><span class="MarketCard-changesPts">---</span><span class="MarketCard-changesPct">---</span></div></div><div class="MarketCard-row"></div></a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/30/european-markets-await-euro-zone-inflation-data.html">European markets climb as investors track euro zone inflation data</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/29/stock-market-futures-open-to-close-news.html" title="U.S. futures">U.S. futures</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/quotes/US10Y" title="U.S. 10-year yield">U.S. 10-year yield</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/29/why-cathie-wood-thinks-bitcoin-will-still-hit-1-million-by-2030-and-benefit-from-the-ftx-collapse.html" title="Pro: Cathie Wood on crypto">Pro: Cathie Wood on crypto</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/29/domestic-and-international-tourist-crowds-traveling-in-japan.html" title="Japan tourism">Japan tourism</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/29/china-says-covid-vaccination-rates-for-seniors-has-climbed-over-the-last-two-weeks.html" title="China Covid">China Covid</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/29/charts-suggest-the-sp-500-is-at-a-make-or-break-moment-jim-cramer-says.html" title="S&amp;P 500 'make or break' moment?">S&amp;P 500 'make or break' moment?</a>
# <class 'bs4.element.Tag'>   <a href="https://www.cnbc.com/2022/11/30/transitory-inflation-talk-is-back-but-economists-say-higher-prices-here-to-stay.html" title="Transitory inflation talk is back. But economists say higher prices are here to stay"><div><picture data-test="Picture"><source height="554" media="(min-width: 1340px)" srcset="https://image.cnbcfm.com/api/v1/image/107142587-16669708682022-10-28t125722z_1337942634_rc2mct9xsoyd_rtrmadp_0_usa-economy-costs.jpeg?v=1669789766&amp;w=830&amp;h=554&amp;ffmt=webp&amp;vtcrop=y" type="image/webp" width="830"/><source height="512" media="(min-width: 1020px)" srcset="https://image.cnbcfm.com/api/v1/image/107142587-16669708682022-10-28t125722z_1337942634_rc2mct9xsoyd_rtrmadp_0_usa-economy-costs.jpeg?v=1669789766&amp;w=610&amp;h=512&amp;ffmt=webp&amp;vtcrop=y" type="image/webp" width="610"/><source height="730" media="(min-width: 760px)" srcset="https://image.cnbcfm.com/api/v1/image/107142587-16669708682022-10-28t125722z_1337942634_rc2mct9xsoyd_rtrmadp_0_usa-economy-costs.jpeg?v=1669789766&amp;w=960&amp;h=730&amp;ffmt=webp&amp;vtcrop=y" type="image/webp" width="960"/><source height="470" media="(min-width: 0px)" srcset="https://image.cnbcfm.com/api/v1/image/107142587-16669708682022-10-28t125722z_1337942634_rc2mct9xsoyd_rtrmadp_0_usa-economy-costs.jpeg?v=1669789766&amp;w=560&amp;h=470&amp;ffmt=webp&amp;vtcrop=y" type="image/webp" width
# <class 'bs4.element.Tag'>   <a href="//www.cnbc.com/rss-feeds/" target="_blank"><span class="icon-social_rss"></span></a>
# <class 'bs4.element.Tag'>   <a href="//www.cnbc.com/news-tips/"><div class="CNBCFooter-linkButton">Get In Touch</div></a>
# <class 'bs4.element.Tag'>   <a href="https://together.nbcuni.com/advertise/?utm_source=cnbc&amp;utm_medium=referral&amp;utm_campaign=property_ad_pages" target="_blank"><div class="CNBCFooter-linkButton">Please Contact Us</div></a>
# <class 'bs4.element.Tag'>   <a href="//www.cnbc.com/sign-up-for-cnbc-newsletters/"><div class="CNBCFooter-linkButton">Sign Up Now</div></a>
# <class 'bs4.element.Tag'>   <a class="CNBCFooter-privacyLink" href="https://www.nbcuniversal.com/privacy?intake=CNBC" target="_blank">Privacy Policy</a>
# <class 'bs4.element.Tag'>   <a class="CNBCFooter-privacyLink" href="https://www.nbcuniversal.com/privacy/notrtoo?intake=CNBC" target="_blank">Do Not Sell My Personal Information</a>
# <class 'bs4.element.Tag'>   <a class="CNBCFooter-privacyLink" href="https://www.nbcuniversal.com/privacy/california-consumer-privacy-act?intake=CNBC" target="_blank">CA Notice</a>
# <class 'bs4.element.Tag'>   <a class="CNBCFooter-privacyLink" href="/nbcuniversal-terms-of-service/">Terms of Service</a>
# <class 'bs4.element.Tag'>   <a href="https://www.nbcuniversal.com" target="_blank">A Division of NBCUniversal</a>
# <class 'bs4.element.Tag'>   <a href="/market-data-terms-of-service/">Market Data Terms of Use and Disclaimers</a>
# <class 'bs4.element.Tag'>   <a href="//www.cnbc.com/market-data-terms-of-service/"><img alt="Reuters" class="CNBCFooter-reutersLogo" src="https://static-redesign.cnbcfm.com/dist/09c161b9810767a7849e.svg"/></a>
# "International Business, World News & Global Stock Market AnalysisSkip NavigationMarketsPre-MarketsU.S. MarketsEurope MarketsChina MarketsAsia MarketsWorld MarketsCurrenciesCryptocurrencyFutures & CommoditiesBondsFunds & ETFsBusinessEconomyFinanceHealth & ScienceMediaReal EstateEnergyClimateTransportationIndustrialsRetailWealthLifeSmall BusinessInvestingPersonal FinanceFintechFinancial AdvisorsOptions ActionETF StreetBuffett ArchiveEarningsTrader TalkTechCybersecurityEnterpriseInternetMediaMobileSocial MediaCNBC Disruptor 50Tech GuidePoliticsWhite HousePolicyDefenseCongressEquity and OpportunityEurope PoliticsChina PoliticsAsia PoliticsWorld PoliticsCNBC TVLive AudioLatest VideoTop VideoCEO InterviewsEurope TVAsia TVCNBC PodcastsDigital OriginalsWatchlistInvesting ClubTrust PortfolioAnalysisTrade AlertsVideoEducationPROPro NewsPro LiveSubscribeSign InMenuMake ItUSAINTLSearch quotes, news & videosWatchlistSIGN INCreate free accountMarketsBusinessInvestingTechPoliticsCNBC TVWatchlistInvesting ClubPROMenuEURASIAASIA FXCRYPTOUSPRE-MKTOILBONDSGOLDEUR FX---------------------------------------------European markets climb as investors track euro zone inflation dataQuick LinksQuick LinksU.S. futuresU.S. 10-year yieldPro: Cathie Wood on cryptoJapan tourismChina CovidS&P 500 'make or break' moment?Transitory inflation talk is back. But economists say higher prices are here to stayStock futures inch up as Wall Street awaits Fed Chair Powell's speech Fed Chair Jerome Powell is once again the center of attention for markets China could reopen in March, but zero-Covid has shaken confidence in supply chains, economist saysEurope's biggest buyer of bonds is starting to think about sellingLatest News23 Min AgoSingapore's deputy prime minister calls FTX loss 'disappointing'28 Min AgoTreasury yields dip as investors await key labor market data 1 Hour AgoRussia 'planning something' in southern Ukraine, Kyiv warns; Russians could be advancing in Donetsk2 Hours AgoEurope's biggest buyer of bonds is starting to think about selling2 Hours AgoBitcoin tops $17,000 — but analysts don't expect the bounce to stick2 Hours AgoChina could reopen in March, but zero-Covid has shaken confidence, economist says3 Hours AgoTransitory inflation talk is back. But economists say higher prices are here to stay4 Hours AgoTencent bets on cloud computing growth abroad amid domestic gaming slowdown4 Hours AgoPeter Thiel's VC fund backs TreeCard, a fintech that plants trees when you spend4 Hours AgoEuropean markets climb as investors track euro zone inflation data5 Hours AgoDrug overdose deaths among seniors have more than tripled in two decades9 Hours AgoDouble-digit percentage drop could hit stocks in early 2023: Morgan Stanley9 Hours AgoCramer's lightning round: I like Morgan Stanley over SoFi Technologies10 Hours AgoAs Wall Street gets bearish, these stocks with margin growth could be safe bets10 Hours AgoGoldman's Currie says oil stocks are trading 'far below' their long-term trend10 Hours AgoCharts suggest the S&P 500 is at a ‘make-or-break’ moment, Jim Cramer says10 Hours AgoChina's factory activity at lowest reading since April; Hong Kong stocks briefly rise 2%11 Hours AgoJim Cramer says he likes stocks in these 4 industries over tech right now11 Hours AgoStock futures inch up as Wall Street awaits Fed Chair Powell's speech11 Hours AgoKroger, Albertsons CEOs defend grocery tie-up, say deal won't hurt competition12 Hours AgoPro Picks: Watch all of Tuesday's big stock calls on CNBC12 Hours AgoEnergy stocks could double next year even in a flat market, according to Fundstrat's Tom Lee12 Hours AgoCongressional leaders clear the way for bill to avert a railroad strike 12 Hours AgoCrowdStrike shares tumble on weaker-than-expected growth in new revenue12 Hours AgoStocks making the biggest moves after hours: Workday, CrowdStrike, Horizon, more12 Hours AgoTrump ex-chief of staff Meadows ordered to testify in Georgia election probe13 Hours AgoElon Musk may be luring Apple int ...

# %% [markdown]
# # QUESTION 8
# Write a python program to scrape the details of most downloaded articles from AI in last 90 days.
#
# https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles
# Scrape mentioned below Details:
#
# i)TITLE

# %%
from bs4 import BeautifulSoup as bs
import requests as rq
import re
import pandas as pd 
url = 'https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles'

data = rq.get(url)
html_data = data.content
 
Soup = bs(data.text, 'html.parser')
 
header_data = Soup.find_all('h2')

print('Following is the of most downloaded articles TITLES referred from', url, ':', '\n')
a=1
for i in header_data:
    print(a,'.',i.text.strip())
    a = a+1
# Out:
# Following is the of most downloaded articles TITLES referred from https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles :
#
# 1 . Reward is enough
# 2 . Making sense of raw input
# 3 . Law and logic: A review from an argumentation perspective
# 4 . Creativity and artificial intelligence
# 5 . Artificial cognition for social human–robot interaction: An implementation
# 6 . Explanation in artificial intelligence: Insights from the social sciences
# 7 . Making sense of sensory input
# 8 . Conflict-based search for optimal multi-agent pathfinding
# 9 . Between MDPs and semi-MDPs: A framework for temporal abstraction in reinforcement learning
# 10 . The Hanabi challenge: A new frontier for AI research
# 11 . Evaluating XAI: A comparison of rule-based and example-based explanations
# 12 . Argumentation in artificial intelligence
# 13 . Algorithms for computing strategies in two-player simultaneous move games
# 14 . Multiple object tracking: A literature review
# 15 . Selection of relevant features and examples in machine learning
# 16 . A survey of inverse reinforcement learning: Challenges, methods and progress
# 17 . Explaining individual predictions when features are dependent: More accurate approximations to Shapley values
# 18 . A review of possible effects of cognitive biases on interpretation of rule-based machine learning models
# 19 . Integrating social power into the decision-making of cognitive agents
# 20 . “That's (not) the output I expected!” On the role of end user expectations in creating explanations of AI systems
# 21 . Explaining black-box classifiers using post-hoc explanations-by-example: The effect of explanations and error-rates in XAI user studies
# 22 . Algorithm runtime prediction: Methods & evaluation
# 23 . Wrappers for feature subset selection
# 24 . Commonsense visual sensemaking for autonomous driving – On generalised neurosymbolic online abduction integrating vision and semantics
# 25 . Quantum computation, quantum theory and AI

# %% [markdown]
# # QUESTION-8
#
# ii)AUTHORS

# %%
from bs4 import BeautifulSoup as bs
import requests as rq
import re
import pandas as pd 
url = 'https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles'


data = rq.get(url)
html_data = data.content
 
Soup = bs(html_data, 'html.parser')
 
header_data = Soup.find_all(class_='sc-1w3fpd7-0 pgLAT',)

print('Following is the of most downloaded authors referred from', url, ':', '\n')
a=1
for i in header_data:
    print(a,'.',i.text.strip())
    a = a+1
# Out:
# Following is the of most downloaded authors referred from https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles :

# %% [markdown]
# # QUESTION-8
#
# iii)PUBLISHED DATE

# %%
from bs4 import BeautifulSoup as bs
import requests as rq
import re
import pandas as pd 
url = 'https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles'


data = rq.get(url)
html_data = data.content
 
Soup = bs(html_data, 'html.parser')
 
header_data = Soup.find_all(class_='sc-1thf9ly-2 bKddwo',)

print('Following is the of Dates for most downloaded authors referred from', url, ':', '\n')
a=1
for i in header_data:
    print(a,'.',i.text.strip())
    a = a+1
    print(a)
# Out:
# Following is the of Dates for most downloaded authors referred from https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles :

# %% [markdown]
# # QUESTION-8
#
# iv)PAPER URL

# %%
url = 'https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles '
data = rq.get(url)
html_data = data.content
 
Soup = bs(data.text, 'html.parser')
 

header_data = Soup.find_all('a',)

for a in header_data:
    print ( "News URL:", a['href'])
# Out:
# News URL: #skip-to-content-anchor
# News URL: http://www.elsevier.com
# News URL: https://account.elsevier.com/auth
# News URL: https://elsevier.com/about
# News URL: https://www.elsevier.com/connect
# News URL: https://www.elsevier.com/about/careers
# News URL: https://elsevier.com/about
# News URL: https://www.elsevier.com/connect
# News URL: https://www.elsevier.com/about/careers
# News URL: https://www.elsevier.com/rd-solutions
# News URL: https://www.elsevier.com/clinical-solutions
# News URL: https://www.elsevier.com/research-platforms
# News URL: https://www.elsevier.com/research-intelligence
# News URL: https://www.elsevier.com/education
# News URL: https://www.elsevier.com/solutions
# News URL: https://www.elsevier.com/rd-solutions
# News URL: https://www.elsevier.com/clinical-solutions
# News URL: https://www.elsevier.com/research-platforms
# News URL: https://www.elsevier.com/research-intelligence
# News URL: https://www.elsevier.com/education
# News URL: https://www.elsevier.com/solutions
# News URL: https://www.elsevier.com/authors
# News URL: https://www.elsevier.com/editors
# News URL: https://www.elsevier.com/reviewers
# News URL: https://www.elsevier.com/librarians
# News URL: https://www.elsevier.com/strategic-partners
# News URL: https://www.elsevier.com/open-access
# News URL: https://www.elsevier.com/societies
# News URL: https://www.elsevier.com/authors
# News URL: https://www.elsevier.com/editors
# News URL: https://www.elsevier.com/reviewers
# News URL: https://www.elsevier.com/librarians
# News URL: https://www.elsevier.com/strategic-partners
# News URL: https://www.elsevier.com/open-access
# News URL: https://www.elsevier.com/societies
# News URL: https://www.elsevier.com/books-and-journals
# News URL: https://webshop.elsevier.com/?utm_source=ecom&utm_medium=top&utm_campaign=webshop
# News URL: https://www.elsevier.com/books-and-journals
# News URL: https://webshop.elsevier.com/?utm_source=ecom&utm_medium=top&utm_campaign=webshop
# News URL: https://global-checkout.elsevier.com
# News URL: https://account.elsevier.com/auth
# News URL: https://www.elsevier.com/
# News URL: https://www.elsevier.com/authors/submit-your-paper
# News URL: https://www.sciencedirect.com/
# News URL: https://www.elsevier.com/search-results?labels=journals
# News URL: https://www.elsevier.com
# News URL: //www.elsevier.com/legal/elsevier-website-terms-and-conditions
# News URL: //www.elsevier.com/legal/privacy-policy
# News URL: //www.elsevier.com/legal/cookienotice
# News URL: //www.elsevier.com/sitemap
# News URL: https://www.relx.com/

# %% [markdown]
# # QUESTION-9
# Write a python program to scrape details from mention details from dineout.co.in
#
# i)Restaurant name
#
# ii)cuisine
#
# iii)location
#
# Iv)Ratings
#
# v)image URL

# %%
page=requests.get('https://www.dineout.co.in/delhi-restaurants/welcome-back')
page

soup=BeautifulSoup(page.content)
soup


RN=[]
for i in soup.find_all('div',class_="restnt-info cursor"):
    RN.append(i.text)
    
RN


price=[]
for i in soup.find_all('span',class_="double-line-ellipsis"):
    price.append(i.text)
    
price


location=[]
for i in soup.find_all('div',class_="restnt-loc ellipsis"):
    location.append(i.text)
    
location


images=[]
for i in soup.find_all('img',class_="no-img"):
    images.append(i['data-src'])
    
images


RT=[]
for i in soup.find_all('div',class_="restnt-rating rating-4"):
    RT.append(i.text)
    
RT


import pandas as pd
df=pd.DataFrame({"Restaurant Name":RN, "Cusines":price, "Location":location, "Ratings":RT,"Images_Url":images})
df
# Out:
#                                       Restaurant Name  \
# 0               TamashaConnaught Place, Central Delhi
# 1   LocalScindia House,Connaught Place, Central Delhi
# 2   Station BarF-Block,Connaught Place, Central Delhi
# 3   Ministry Of BeerM-Block,Connaught Place, Centr...
# 4   Unplugged CourtyardConnaught Place, Central Delhi
# 5                   QBAConnaught Place, Central Delhi
# 6     The Junkyard CafeConnaught Place, Central Delhi
# 7   The G.T. ROADM-Block,Connaught Place, Central ...
# 8   The Luggage Room By SandozM-Block,Connaught Pl...
# 9   My Bar HeadquartersConnaught Place, Central Delhi
# 10                ChidoConnaught Place, Central Delhi
# 11  Ardor 2.1 Restaurant and LoungeConnaught Place...
# 12  Connaught Clubhouse MicrobreweryConnaught Plac...
# 13               SandozConnaught Place, Central Delhi
# 14  Out Of The Box CourtyardConnaught Place, Centr...
# 15       Openhouse CafeConnaught Place, Central Delhi
# 16  Chili's American Grill and BarM-Block,Connaugh...
# 17              Berco'sConnaught Place, Central Delhi
# 18  38 BarracksM-Block,Connaught Place, Central Delhi
# 19           Cafe Delhi HeightsJanpath, Central Delhi
# 20    Wok in the CloudsConnaught Place, Central Delhi
#
#                                               Cusines  \
# 0   ₹ 2,000 for 2 (approx) | Continental, Asian, I...
# 1   ₹ 2,000 for 2 (approx) | North Indian, Asian, ...
# 2   ₹ 1,100 for 2 (approx) | Italian, Chinese, Nor...
# 3   ₹ 3,000 for 2 (approx) | North Indian, Contine...
# 4   ₹ 3,300 for 2 (approx) | North Indian, Italian...
# 5   ₹ 2,100 for 2 (approx) | North Indian, Contine...
# 6   ₹ 2,100 for 2 (approx) | North Indian, Contine...
# 7               ₹ 1,400 for 2 (approx) | North Indian
# 8   ₹ 1,600 for 2 (approx) | Chinese, Italian, Nor...
# 9      ₹ 1,500 for 2 (approx) | North Indian, Chinese
# 10  ₹ 1,800 for 2 (approx) | North Indian, Italian...
# 11  ₹ 2,000 for 2 (approx) | North Indian, Chinese...
# 12  ₹ 1,800 for 2 (approx) | North Indian, Contine...
# 13  ₹ 1,400 for 2 (approx) | North Indian, Chinese...
# 14  ₹ 2,200 for 2 (approx) | North Indian, Mediter...
# 15  ₹ 2,000 for 2 (approx) | North Indian, Asian, ...
# 16  ₹ 2,000 for 2 (approx) | Mexican, American, Te...
# 17             ₹ 1,300 for 2 (approx) | Chinese, Thai
# 18  ₹ 2,700 for 2 (approx) | North Indian, Chinese...
# 19  ₹ 1,300 for 2 (approx) | Continental, North In...
# 20  ₹ 2,200 for 2 (approx) | Chinese, Thai, Contin...
#
#                                         Location Ratings  \
# 0                 Connaught Place, Central Delhi     4.2
# 1   Scindia House,Connaught Place, Central Delhi       4
# 2         F-Block,Connaught Place, Central Delhi       4
# 3         M-Block,Connaught Place, Central Delhi       4
# 4                 Connaught Place, Central Delhi       4
# 5                 Connaught Place, Central Delhi     4.3
# 6                 Connaught Place, Central Delhi     4.1
# 7         M-Block,Connaught Place, Central Delhi     4.3
# 8         M-Block,Connaught Place, Central Delhi     3.9
# 9                 Connaught Place, Central Delhi       4
# 10                Connaught Place, Central Delhi     4.2
# 11                Connaught Place, Central Delhi     3.8
# 12                Connaught Place, Central Delhi     4.3
# 13                Connaught Place, Central Delhi       4
# 14                Connaught Place, Central Delhi     4.1
# 15                Connaught Place, Central Delhi     4.1
# 16        M-Block,Connaught Place, Central Delhi     4.3
# 17                Connaught Place, Central Delhi     4.3
# 18        M-Block,Connaught Place, Central Delhi     4.3
# 19                        Janpath, Central Delhi     4.3
# 20                Connaught Place, Central Delhi     4.3
#
#                                            Images_Url
# 0   https://im1.dineout.co.in/images/uploads/resta...
# 1   https://im1.dineout.co.in/images/uploads/resta...
# 2   https://im1.dineout.co.in/images/uploads/resta...
# 3   https://im1.dineout.co.in/images/uploads/resta...
# 4   https://im1.dineout.co.in/images/uploads/resta...
# 5   https://im1.dineout.co.in/images/uploads/resta...
# 6   https://im1.dineout.co.in/images/uploads/resta...
# 7   https://im1.dineout.co.in/images/uploads/resta...
# 8   https://im1.dineout.co.in/images/uploads/resta...
# 9   https://im1.dineout.co.in/images/uploads/resta...
# 10  https://im1.dineout.co.in/images/uploads/resta...
# 11  https://im1.dineout.co.in/images/uploads/resta...
# 12  https://im1.dineout.co.in/images/uploads/resta...
# 13  https://im1.dineout.co.in/images/uploads/resta...
# 14  https://im1.dineout.co.in/images/uploads/resta...
# 15  https://im1.dineout.co.in/images/uploads/resta...
# 16  https://im1.dineout.co.in/images/uploads/resta...
# 17  https://im1.dineout.co.in/images/uploads/resta...
# 18  https://im1.dineout.co.in/images/uploads/resta...
# 19  https://im1.dineout.co.in/images/uploads/resta...
# 20  https://im1.dineout.co.in/images/uploads/resta...

# %% [markdown]
# # QUESTION-10
# Write a python program to scrape the details of top publication from Google Scholar from
#
# https://scholar.google.com/citations?view_op=top_venues&hl=en

# %%
page=requests.get('https://scholar.google.com/citations?view_op=top_venues&hl=en')
page


book=BeautifulSoup(page.content)
book


Rank=[]
for i in book.find_all('td',class_='gsc_mvt_p'):
   Rank.append(i.text)
Rank


Pub=[]
for i in book.find_all('td',class_='gsc_mvt_t'):
   Pub.append(i.text)
Pub


H5=[]
for i in book.find_all('a',class_='gs_ibl gsc_mp_anchor'):
   H5.append(i.text)
H5


h5=[]
for i in book.find_all('span',class_='gs_ibl gsc_mp_anchor'):
   h5.append(i.text)
h5


import pandas as pd
df=pd.DataFrame({"Rank":Rank,"Publication":Pub,"H5 Ixdex":H5,"H5 Median":h5})
df
# Out:
#     Rank                                        Publication H5 Ixdex H5 Median
# 0     1.                                             Nature      444       667
# 1     2.                The New England Journal of Medicine      432       780
# 2     3.                                            Science      401       614
# 3     4.  IEEE/CVF Conference on Computer Vision and Pat...      389       627
# 4     5.                                         The Lancet      354       635
# ..   ...                                                ...      ...       ...
# 95   96.                       Journal of Business Research      145       233
# 96   97.                                   Molecular Cancer      145       209
# 97   98.                                            Sensors      145       201
# 98   99.                              Nature Climate Change      144       228
# 99  100.                    IEEE Internet of Things Journal      144       212
#
# [100 rows x 4 columns]
